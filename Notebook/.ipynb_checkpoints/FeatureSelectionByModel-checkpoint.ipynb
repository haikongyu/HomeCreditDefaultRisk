# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['font.sans-serif'] = [u'SimHei']
plt.rcParams['font.size'] = 12
plt.rcParams['axes.unicode_minus'] = False
from sklearn.model_selection import train_test_split
import xgboost as xgb
import class_function as cf
import copy
import numpy as np

# %%
data = pd.read_csv('../Data/del_features_with_K_S.csv')
data
# Out:
#                                           del_feature       K-S
# 0                                REGION_RATING_CLIENT  0.411453
# 1                                       FLOORSMAX_AVG  0.411419
# 2                                      FLAG_EMP_PHONE  0.409924
# 3          pre_app_merged_NAME_YIELD_GROUP_low_normal  0.412678
# 4               bureau_merged_CREDIT_TYPE_Credit card  0.412827
# 5         pre_app_merged_NAME_CONTRACT_STATUS_Refused  0.412641
# 6                                     FLAG_DOCUMENT_3  0.410691
# 7          pre_app_merged_cash_CNT_INSTALMENT_max_std  0.412497
# 8      pre_app_merged_PRODUCT_COMBINATION_Card Street  0.411174
# 9        pre_app_merged_DAYS_LAST_DUE_1ST_VERSION_std  0.411379
# 10         pre_app_merged_NAME_YIELD_GROUP_low_action  0.412138
# 11           pre_app_merged_NAME_PRODUCT_TYPE_walk-in  0.408660
# 12                   pre_app_merged_DAYS_DECISION_min  0.411915
# 13                pre_app_merged_NAME_CLIENT_TYPE_New  0.411440
# 14               pre_app_merged_RATE_DOWN_PAYMENT_max  0.411950
# 15              bureau_merged_DAYS_CREDIT_ENDDATE_min  0.410404
# 16                         REGION_POPULATION_RELATIVE  0.410913
# 17               bureau_merged_DAYS_ENDDATE_FACT_mean  0.410255
# 18         pre_app_merged_cash_CNT_INSTALMENT_std_std  0.410450
# 19  pre_app_merged_PRODUCT_COMBINATION_POS industr...  0.409084
# 20              pre_app_merged_DAYS_FIRST_DRAWING_min  0.409331
# 21                 bureau_merged_CREDIT_ACTIVE_Closed  0.409809
# 22                                    OCCUPATION_TYPE  0.409443
# 23                             REG_CITY_NOT_LIVE_CITY  0.409062
# 24            pre_app_merged_CODE_REJECT_REASON_SCOFR  0.409926
# 25                             REG_CITY_NOT_WORK_CITY  0.410645
# 26  pre_app_merged_NAME_PAYMENT_TYPE_Cash through ...  0.410261
# 27                pre_app_merged_NAME_YIELD_GROUP_XNA  0.409373
# 28  pre_app_merged_PRODUCT_COMBINATION_Cash X-Sell...  0.410333
# 29  pre_app_merged_NAME_CONTRACT_TYPE_Revolving loans  0.411178
# 30   pre_app_merged_NAME_CONTRACT_TYPE_Consumer loans  0.410773
# 31            pre_app_merged_CODE_REJECT_REASON_LIMIT  0.410532
# 32                     pre_app_merged_CNT_PAYMENT_min  0.408299
# 33                     pre_app_merged_CNT_PAYMENT_std  0.407754
# 34                    pre_app_merged_CNT_PAYMENT_mean  0.408678
# 35               pre_app_merged_CODE_REJECT_REASON_HC  0.405636
# 36                                  ORGANIZATION_TYPE  0.406771
# 37          pre_app_merged_NAME_CLIENT_TYPE_Refreshed  0.405347
# 38  pre_app_merged_installments_DAYS_INSTALMENT_ma...  0.407825
# 39  pre_app_merged_installments_DAYS_INSTALMENT_mi...  0.406841
# 40                                  DAYS_REGISTRATION  0.404983
# 41                      bureau_merged_DAYS_CREDIT_max  0.404530
# 42                  pre_app_merged_DAYS_LAST_DUE_mean  0.402776
# 43                                 NAME_FAMILY_STATUS  0.399731
# 44                                    DAYS_ID_PUBLISH  0.397839
# 45                                     TOTALAREA_MODE  0.396943
# 46                      bureau_merged_DAYS_CREDIT_min  0.398227
# 47                        REGION_RATING_CLIENT_W_CITY  0.395238

# %%
fig, ax = plt.subplots()
ax.set_xlabel('删除特征数')
ax.set_ylabel('K-S值')
ax.set_title('K-S值随特征减少变化')
ax.plot(data.index, data['K-S'], c = 'r')
plt.show()

# %%
data = pd.read_csv('../Data/result_iv_selected.csv')
print(data.shape)
data.head()
# Out:
# (307511, 66)
#    pre_app_merged_NAME_PAYMENT_TYPE_Cash through the bank  \
# 0                                           0.000000
# 1                                           0.666667
# 2                                           1.000000
# 3                                           0.444444
# 4                                           0.833333
#
#    bureau_merged_DAYS_ENDDATE_FACT_max  \
# 0                             0.987530
# 1                             0.812955
# 2                             0.867683
# 3                             0.817462
# 4                             0.728784
#
#    pre_app_merged_NAME_CONTRACT_STATUS_Approved  \
# 0                                      1.000000
# 1                                      1.000000
# 2                                      1.000000
# 3                                      0.555556
# 4                                      1.000000
#
#    bureau_merged_DAYS_ENDDATE_FACT_mean  \
# 0                              0.916731
# 1                              0.868999
# 2                              0.936429
# 3                              0.884163
# 4                              0.906524
#
#    pre_app_merged_CODE_REJECT_REASON_SCOFR  AMT_ANNUITY  \
# 0                                      0.0     0.090032
# 1                                      0.0     0.132924
# 2                                      0.0     0.020025
# 3                                      0.0     0.109477
# 4                                      0.0     0.078975
#
#    pre_app_merged_DAYS_LAST_DUE_1ST_VERSION_std  \
# 0                                      0.268323
# 1                                      0.003285
# 2                                      0.268323
# 3                                      0.701032
# 4                                      0.003584
#
#    pre_app_merged_installments_DAYS_INSTALMENT_min_std  TOTALAREA_MODE  \
# 0                                           0.314011          0.014900
# 1                                           0.442411          0.071400
# 2                                           0.314011          0.102547
# 3                                           0.098927          0.102547
# 4                                           0.383059          0.102547
#
#    EXT_SOURCE_3  ...  ORGANIZATION_TYPE  REGION_RATING_CLIENT  FLAG_EMP_PHONE  \
# 0      0.155054  ...                  0                     0               0
# 1      0.569889  ...                  1                     1               0
# 2      0.814130  ...                  2                     0               0
# 3      0.569889  ...                  0                     0               0
# 4      0.569889  ...                  3                     0               0
#
#    FLAG_DOCUMENT_3  NAME_FAMILY_STATUS  NAME_EDUCATION_TYPE  \
# 0                0                   0                    0
# 1                0                   1                    1
# 2                1                   0                    0
# 3                0                   2                    0
# 4                1                   0                    0
#
#    REG_CITY_NOT_LIVE_CITY  NAME_INCOME_TYPE  REG_CITY_NOT_WORK_CITY  TARGET
# 0                       0                 0                       0       1
# 1                       0                 1                       0       0
# 2                       0                 0                       0       0
# 3                       0                 0                       0       0
# 4                       0                 0                       1       0
#
# [5 rows x 66 columns]

# %%
X = data.drop(columns = ['TARGET'])
Y = data.TARGET
print(X.shape)
# Out:
# (307511, 65)

# %%
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=0)
mxg_cla = cf.Multi_XGB(max_depth=7, n_estimators=200, random_state=0, colsample_bylevel = 0.2, n_jobs = 8)
mxg_cla.train(x_train, y_train)
mxg_cla.predict(x_test)
mxg_cla.cal_K_S(y_test)
mxg_cla.K_S
# Out:
# 0.4096665283040108

# %% [markdown]
# features = list(X.columns)
# del_features = []
# K_S_list = []
# X_0 = copy.deepcopy(X)
# while features:
#     X_0 = X_0[features]
#     K_S_ = []
#     i = 0
#     for feature in features:
#         X_tmp = X_0.drop(columns = [feature])
#
#         x_train, x_test, y_train, y_test = train_test_split(X_tmp, Y, test_size=0.2, random_state=0)
#         mxg_cla = cf.Multi_XGB(max_depth=7, n_estimators=200, random_state=0, colsample_bylevel = 0.2, n_jobs = 8)
#         mxg_cla.train(x_train, y_train)
#         mxg_cla.predict(x_test)
#         mxg_cla.cal_K_S(y_test)
#         K_S_.append(mxg_cla.K_S)
#         print(i)
#         i += 1
#
#     del_feature = features[np.argmax(K_S_)]
#     del_features.append(del_feature)
#     K_S_list.append(max(K_S_))
#
#     df = pd.DataFrame({'del_feature': del_features, 'K-S': K-S_list})
#     df.to_csv('../Data/del_features_with_K_S.csv', index = False, encoding = 'utf-8_sig')
#
#     features = features.remove(del_feature)
#     print('*' * 10, len(features), '*' * 10)

# %%
a = [1, 2, 6, 3]

# %%
a = a.remove(a[0])

# %%
a

# %%
a == None
# Out:
# True
