# %%
import class_function as cf
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
import xgboost as xgb
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv('../Data/result_5_merged.csv')
X = data.drop(columns=['TARGET'])
Y = data.TARGET

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=0)

# %%
import xgboost as xgb
from sklearn.metrics import mean_squared_error

# %%
y_train.value_counts()
# Out:
# 0    226038
# 1     19970
# Name: TARGET, dtype: int64

# %%
226038/19970
# Out:
# 11.318878317476214

# %%
xg_cla = xgb.XGBClassifier(max_depth=10, n_estimators=500, random_state=0)

#模型训练
xg_cla.fit(x_train,y_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=10, min_child_weight=1, missing=None, n_estimators=500,
#        n_jobs=1, nthread=None, objective='binary:logistic', random_state=0,
#        reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#        silent=True, subsample=1)

# %%
y_proba = xg_cla.predict_proba(x_test)
y_proba
# Out:
# array([[0.716985  , 0.28301498],
#        [0.9907394 , 0.00926061],
#        [0.91283065, 0.08716934],
#        ...,
#        [0.99154764, 0.00845233],
#        [0.79589385, 0.20410615],
#        [0.854594  , 0.145406  ]], dtype=float32)

# %%
xg_cla.predict(x_test)[0]
# Out:
# 0

# %%
import importlib
importlib.reload(cf)

threshold_list = np.arange(0, 1, 0.01)
accuracy_list = []
recall_list = []
precision_list = []
MissingAlarm_list = []
FalseAlarm_list = []
F1_list = []
fpr_list = []

for threshold in threshold_list:
    y_predicted = []
    for proba_list in y_proba:
        if proba_list[0] > threshold:
            y_predicted.append(0)
        else:
            y_predicted.append(1)
            
    fbc = cf.For_binary_classifier(y_predicted, y_test)
    accuracy_list.append(fbc.accuracy)
    recall_list.append(fbc.recall)
    precision_list.append(fbc.precision)
    MissingAlarm_list.append(fbc.MissingAlarm)
    FalseAlarm_list.append(fbc.FalseAlarm)
    F1_list.append(fbc.F1)
    fpr_list.append(fbc.fpr)
    print('*' * 40)
# Out:
#                     Real +          Real -
#    Predict +           0               0
#    Predict -         4855            56648
#
# 准确率： 0.9210607612636782
# 召回率： 0.0
# 精准率： 0
#
# 漏警率： 1.0
# 虚警率： 1
# F1: 0
# fpr: 0.0
# ****************************************
#                     Real +          Real -
#    Predict +           0               0
#    Predict -         4855            56648
#
# 准确率： 0.9210607612636782
# 召回率： 0.0
# 精准率： 0
#
# 漏警率： 1.0
# 虚警率： 1
# F1: 0
# fpr: 0.0
# ****************************************
#                     Real +          Real -
#    Predict +           0               0
#    Predict -         4855            56648
#
# 准确率： 0.9210607612636782
# 召回率： 0.0
# 精准率： 0
#
# 漏警率： 1.0
# 虚警率： 1
# F1: 0
# fpr: 0.0
# ****************************************
#                     Real +          Real -
#    Predict +           0               0
#    Predict -         4855            56648
#
# 准确率： 0.9210607612636782
# 召回率： 0.0
# 精准率： 0
#
# 漏警率： 1.0
# 虚警率： 1
# F1: 0
# fpr: 0.0
# ****************************************
#                     Real +          Real -
#    Predict +           0               0
#    Predict -         4855            56648
#
# 准确率： 0.9210607612636782
# 召回率： 0.0
# 精准率： 0
#
# 漏警率： 1.0
# 虚警率： 1
# F1: 0
# fpr: 0.0
# ****************************************
#                     Real +          Real -
#    Predict +           0               1
#    Predict -         4855            56647
#
# 准确率： 0.9210445018942165
# 召回率： 0.0
# 精准率： 0.0
#
# 漏警率： 1.0
# 虚警率： 1.0
# F1: 0
# fpr: 1.7652873887868946e-05
# ****************************************
#                     Real +          Real -
#    Predict +           0               2
#    Predict -         4855            56646
#
# 准确率： 0.9210282425247549
# 召回率： 0.0
# 精准率： 0.0
#
# 漏警率： 1.0
# 虚警率： 1.0
# F1: 0
# fpr: 3.530574777573789e-05
# ****************************************
#                     Real +          Real -
#    Predict +           0               2
#    Predict -         4855            56646
#
# 准确率： 0.9210282425247549
# 召回率： 0.0
# 精准率： 0.0
#
# 漏警率： 1.0
# 虚警率： 1.0
# F1: 0
# fpr: 3.530574777573789e-05
# ****************************************
#                     Real +          Real -
#    Predict +           0               2
#    Predict -         4855            56646
#
# 准确率： 0.9210282425247549
# 召回率： 0.0
# 精准率： 0.0
#
# 漏警率： 1.0
# 虚警率： 1.0
# F1: 0
# fpr: 3.530574777573789e-05
# ****************************************
#                     Real +          Real -
#    Predict +           0               3
#    Predict -         4855            56645
#
# 准确率： 0.9210119831552932
# 召回率： 0.0
# 精准率： 0.0
#
# 漏警率： 1.0
# 虚警率： 1.0
# F1: 0
# fpr: 5.295862166360683e-05
# ****************************************
#                     Real +          Real -
#    Predict +           1               3
#    Predict -         4854            56645
#
# 准确率： 0.9210282425247549
# 召回率： 0.00020597322348094748
# 精准率： 0.25
#
# 漏警率： 0.9997940267765191
# 虚警率： 0.75
# F1: 0.0004116073266104137
# fpr: 5.295862166360683e-05
# ****************************************
#                     Real +          Real -
#    Predict +           2               3
#    Predict -         4853            56645
#
# 准确率： 0.9210445018942165
# 召回率： 0.00041194644696189496
# 精准率： 0.4
#
# 漏警率： 0.9995880535530381
# 虚警率： 0.6
# F1: 0.0008230452674897119
# fpr: 5.295862166360683e-05
# ****************************************
#                     Real +          Real -
#    Predict +           2               3
#    Predict -         4853            56645
#
# 准确率： 0.9210445018942165
# 召回率： 0.00041194644696189496
# 精准率： 0.4
#
# 漏警率： 0.9995880535530381
# 虚警率： 0.6
# F1: 0.0008230452674897119
# fpr: 5.295862166360683e-05
# ****************************************
#                     Real +          Real -
#    Predict +           2               3
#    Predict -         4853            56645
#
# 准确率： 0.9210445018942165
# 召回率： 0.00041194644696189496
# 精准率： 0.4
#
# 漏警率： 0.9995880535530381
# 虚警率： 0.6
# F1: 0.0008230452674897119
# fpr: 5.295862166360683e-05
# ****************************************
#                     Real +          Real -
#    Predict +           3               3
#    Predict -         4852            56645
#
# 准确率： 0.9210607612636782
# 召回率： 0.0006179196704428424
# 精准率： 0.5
#
# 漏警率： 0.9993820803295571
# 虚警率： 0.5
# F1: 0.001234313927175478
# fpr: 5.295862166360683e-05
# ****************************************
#                     Real +          Real -
#    Predict +           3               3
#    Predict -         4852            56645
#
# 准确率： 0.9210607612636782
# 召回率： 0.0006179196704428424
# 精准率： 0.5
#
# 漏警率： 0.9993820803295571
# 虚警率： 0.5
# F1: 0.001234313927175478
# fpr: 5.295862166360683e-05
# ****************************************
#                     Real +          Real -
#    Predict +           4               4
#    Predict -         4851            56644
#
# 准确率： 0.9210607612636782
# 召回率： 0.0008238928939237899
# 精准率： 0.5
#
# 漏警率： 0.9991761071060762
# 虚警率： 0.5
# F1: 0.001645075056549455
# fpr: 7.061149555147578e-05
# ****************************************
#                     Real +          Real -
#    Predict +           5               4
#    Predict -         4850            56644
#
# 准确率： 0.9210770206331399
# 召回率： 0.0010298661174047373
# 精准率： 0.5555555555555556
#
# 漏警率： 0.9989701338825953
# 虚警率： 0.4444444444444444
# F1: 0.002055921052631579
# fpr: 7.061149555147578e-05
# ****************************************
#                     Real +          Real -
#    Predict +           6               6
#    Predict -         4849            56642
#
# 准确率： 0.9210607612636782
# 召回率： 0.0012358393408856848
# 精准率： 0.5
#
# 漏警率： 0.9987641606591143
# 虚警率： 0.5
# F1: 0.0024655845490034927
# fpr: 0.00010591724332721367
# ****************************************
#                     Real +          Real -
#    Predict +           6               7
#    Predict -         4849            56641
#
# 准确率： 0.9210445018942165
# 召回率： 0.0012358393408856848
# 精准率： 0.46153846153846156
#
# 漏警率： 0.9987641606591143
# 虚警率： 0.5384615384615384
# F1: 0.0024650780608052587
# fpr: 0.00012357011721508262
# ****************************************
#                     Real +          Real -
#    Predict +           7               8
#    Predict -         4848            56640
#
# 准确率： 0.9210445018942165
# 召回率： 0.0014418125643666324
# 精准率： 0.4666666666666667
#
# 漏警率： 0.9985581874356334
# 虚警率： 0.5333333333333333
# F1: 0.002874743326488706
# fpr: 0.00014122299110295156
# ****************************************
#                     Real +          Real -
#    Predict +           8               9
#    Predict -         4847            56639
#
# 准确率： 0.9210445018942165
# 召回率： 0.0016477857878475798
# 精准率： 0.47058823529411764
#
# 漏警率： 0.9983522142121524
# 虚警率： 0.5294117647058824
# F1: 0.0032840722495894913
# fpr: 0.0001588758649908205
# ****************************************
#                     Real +          Real -
#    Predict +          10               9
#    Predict -         4845            56639
#
# 准确率： 0.9210770206331399
# 召回率： 0.0020597322348094747
# 精准率： 0.5263157894736842
#
# 漏警率： 0.9979402677651905
# 虚警率： 0.4736842105263158
# F1: 0.004103405826836274
# fpr: 0.0001588758649908205
# ****************************************
#                     Real +          Real -
#    Predict +          11              11
#    Predict -         4844            56637
#
# 准确率： 0.9210607612636782
# 召回率： 0.0022657054582904223
# 精准率： 0.5
#
# 漏警率： 0.9977342945417096
# 虚警率： 0.5
# F1: 0.004510969858519582
# fpr: 0.0001941816127665584
# ****************************************
#                     Real +          Real -
#    Predict +          12              12
#    Predict -         4843            56636
#
# 准确率： 0.9210607612636782
# 召回率： 0.0024716786817713696
# 精准率： 0.5
#
# 漏警率： 0.9975283213182287
# 虚警率： 0.5
# F1: 0.0049190407870465256
# fpr: 0.00021183448665442733
# ****************************************
#                     Real +          Real -
#    Predict +          16              13
#    Predict -         4839            56635
#
# 准确率： 0.9211095393720632
# 召回率： 0.0032955715756951597
# 精准率： 0.5517241379310345
#
# 漏警率： 0.9967044284243048
# 虚警率： 0.4482758620689655
# F1: 0.006552006552006552
# fpr: 0.00022948736054229627
# ****************************************
#                     Real +          Real -
#    Predict +          18              14
#    Predict -         4837            56634
#
# 准确率： 0.9211257987415248
# 召回率： 0.0037075180226570545
# 精准率： 0.5625
#
# 漏警率： 0.996292481977343
# 虚警率： 0.4375
# F1: 0.007366482504604052
# fpr: 0.00024714023443016524
# ****************************************
#                     Real +          Real -
#    Predict +          21              16
#    Predict -         4834            56632
#
# 准确率： 0.9211420581109865
# 召回率： 0.004325437693099897
# 精准率： 0.5675675675675675
#
# 漏警率： 0.9956745623069001
# 虚警率： 0.43243243243243246
# F1: 0.008585445625511038
# fpr: 0.00028244598220590313
# ****************************************
#                     Real +          Real -
#    Predict +          23              16
#    Predict -         4832            56632
#
# 准确率： 0.9211745768499098
# 召回率： 0.004737384140061792
# 精准率： 0.5897435897435898
#
# 漏警率： 0.9952626158599382
# 虚警率： 0.41025641025641024
# F1: 0.009399264405394361
# fpr: 0.00028244598220590313
# ****************************************
#                     Real +          Real -
#    Predict +          25              18
#    Predict -         4830            56630
#
# 准确率： 0.9211745768499098
# 召回率： 0.005149330587023687
# 精准率： 0.5813953488372093
#
# 漏警率： 0.9948506694129763
# 虚警率： 0.41860465116279066
# F1: 0.010208248264597796
# fpr: 0.000317751729981641
# ****************************************
#                     Real +          Real -
#    Predict +          32              18
#    Predict -         4823            56630
#
# 准确率： 0.9212883924361414
# 召回率： 0.006591143151390319
# 精准率： 0.64
#
# 漏警率： 0.9934088568486097
# 虚警率： 0.36
# F1: 0.013047910295616718
# fpr: 0.000317751729981641
# ****************************************
#                     Real +          Real -
#    Predict +          36              23
#    Predict -         4819            56625
#
# 准确率： 0.9212721330666797
# 召回率： 0.007415036045314109
# 精准率： 0.6101694915254238
#
# 漏警率： 0.9925849639546859
# 虚警率： 0.38983050847457623
# F1: 0.014652014652014652
# fpr: 0.00040601609942098575
# ****************************************
#                     Real +          Real -
#    Predict +          39              27
#    Predict -         4816            56621
#
# 准确率： 0.9212558736972181
# 召回率： 0.008032955715756952
# 精准率： 0.5909090909090909
#
# 漏警率： 0.9919670442842431
# 虚警率： 0.40909090909090906
# F1: 0.015850436903068484
# fpr: 0.0004766275949724615
# ****************************************
#                     Real +          Real -
#    Predict +          45              29
#    Predict -         4810            56619
#
# 准确率： 0.9213209111750646
# 召回率： 0.009268795056642637
# 精准率： 0.6081081081081081
#
# 漏警率： 0.9907312049433573
# 虚警率： 0.3918918918918919
# F1: 0.01825928180158247
# fpr: 0.0005119333427481994
# ****************************************
#                     Real +          Real -
#    Predict +          48              33
#    Predict -         4807            56615
#
# 准确率： 0.921304651805603
# 召回率： 0.009886714727085478
# 精准率： 0.5925925925925926
#
# 漏警率： 0.9901132852729145
# 虚警率： 0.40740740740740744
# F1: 0.01944894651539708
# fpr: 0.0005825448382996752
# ****************************************
#                     Real +          Real -
#    Predict +          51              39
#    Predict -         4804            56609
#
# 准确率： 0.9212558736972181
# 召回率： 0.010504634397528322
# 精准率： 0.5666666666666667
#
# 漏警率： 0.9894953656024716
# 虚警率： 0.43333333333333335
# F1: 0.02062689585439838
# fpr: 0.0006884620816268889
# ****************************************
#                     Real +          Real -
#    Predict +          53              43
#    Predict -         4802            56605
#
# 准确率： 0.9212233549582948
# 召回率： 0.010916580844490216
# 精准率： 0.5520833333333334
#
# 漏警率： 0.9890834191555098
# 虚警率： 0.44791666666666663
# F1: 0.021409816198747728
# fpr: 0.0007590735771783646
# ****************************************
#                     Real +          Real -
#    Predict +          60              49
#    Predict -         4795            56599
#
# 准确率： 0.9212396143277564
# 召回率： 0.012358393408856848
# 精准率： 0.5504587155963303
#
# 漏警率： 0.9876416065911432
# 虚警率： 0.4495412844036697
# F1: 0.024174053182917005
# fpr: 0.0008649908205055784
# ****************************************
#                     Real +          Real -
#    Predict +          64              53
#    Predict -         4791            56595
#
# 准确率： 0.9212396143277564
# 召回率： 0.013182286302780639
# 精准率： 0.5470085470085471
#
# 漏警率： 0.9868177136972194
# 虚警率： 0.45299145299145294
# F1: 0.025744167337087693
# fpr: 0.0009356023160570541
# ****************************************
#                     Real +          Real -
#    Predict +          68              57
#    Predict -         4787            56591
#
# 准确率： 0.9212396143277564
# 召回率： 0.014006179196704428
# 精准率： 0.544
#
# 漏警率： 0.9859938208032956
# 虚警率： 0.45599999999999996
# F1: 0.027309236947791166
# fpr: 0.0010062138116085299
# ****************************************
#                     Real +          Real -
#    Predict +          71              62
#    Predict -         4784            56586
#
# 准确率： 0.9212070955888331
# 召回率： 0.014624098867147271
# 精准率： 0.5338345864661654
#
# 漏警率： 0.9853759011328528
# 虚警率： 0.46616541353383456
# F1: 0.028468323977546114
# fpr: 0.0010944781810478747
# ****************************************
#                     Real +          Real -
#    Predict +          75              70
#    Predict -         4780            56578
#
# 准确率： 0.9211420581109865
# 召回率： 0.015447991761071062
# 精准率： 0.5172413793103449
#
# 漏警率： 0.984552008238929
# 虚警率： 0.48275862068965514
# F1: 0.030000000000000002
# fpr: 0.0012357011721508262
# ****************************************
#                     Real +          Real -
#    Predict +          82              81
#    Predict -         4773            56567
#
# 准确率： 0.9210770206331399
# 召回率： 0.016889804325437692
# 精准率： 0.5030674846625767
#
# 漏警率： 0.9831101956745623
# 虚警率： 0.49693251533742333
# F1: 0.032682343563172574
# fpr: 0.0014298827849173845
# ****************************************
#                     Real +          Real -
#    Predict +          86              88
#    Predict -         4769            56560
#
# 准确率： 0.9210282425247549
# 召回率： 0.017713697219361484
# 精准率： 0.4942528735632184
#
# 漏警率： 0.9822863027806386
# 虚警率： 0.5057471264367817
# F1: 0.03420163054285146
# fpr: 0.0015534529021324671
# ****************************************
#                     Real +          Real -
#    Predict +          92              99
#    Predict -         4763            56549
#
# 准确率： 0.9209469456774466
# 召回率： 0.018949536560247168
# 精准率： 0.4816753926701571
#
# 漏警率： 0.9810504634397529
# 虚警率： 0.5183246073298429
# F1: 0.0364645263575109
# fpr: 0.0017476345148990256
# ****************************************
#                     Real +          Real -
#    Predict +          96              104
#    Predict -         4759            56544
#
# 准确率： 0.920930686307985
# 召回率： 0.019773429454170956
# 精准率： 0.48
#
# 漏警率： 0.9802265705458291
# 虚警率： 0.52
# F1: 0.037982195845697335
# fpr: 0.0018358988843383702
# ****************************************
#                     Real +          Real -
#    Predict +          105             111
#    Predict -         4750            56537
#
# 准确率： 0.9209632050469083
# 召回率： 0.021627188465499485
# 精准率： 0.4861111111111111
#
# 漏警率： 0.9783728115345005
# 虚警率： 0.5138888888888888
# F1: 0.04141195030565964
# fpr: 0.001959469001553453
# ****************************************
#                     Real +          Real -
#    Predict +          110             128
#    Predict -         4745            56520
#
# 准确率： 0.9207680926133684
# 召回率： 0.02265705458290422
# 精准率： 0.46218487394957986
#
# 漏警率： 0.9773429454170958
# 虚警率： 0.5378151260504201
# F1: 0.04319654427645788
# fpr: 0.002259567857647225
# ****************************************
#                     Real +          Real -
#    Predict +          119             146
#    Predict -         4736            56502
#
# 准确率： 0.9206217582882136
# 召回率： 0.02451081359423275
# 精准率： 0.4490566037735849
#
# 漏警率： 0.9754891864057672
# 虚警率： 0.5509433962264151
# F1: 0.046484374999999994
# fpr: 0.002577319587628866
# ****************************************
#                     Real +          Real -
#    Predict +          128             154
#    Predict -         4727            56494
#
# 准确率： 0.9206380176576753
# 召回率： 0.026364572605561278
# 精准率： 0.45390070921985815
#
# 漏警率： 0.9736354273944388
# 虚警率： 0.5460992907801419
# F1: 0.0498345337745766
# fpr: 0.0027185425787318177
# ****************************************
#                     Real +          Real -
#    Predict +          137             171
#    Predict -         4718            56477
#
# 准确率： 0.920507942701982
# 召回率： 0.028218331616889806
# 精准率： 0.4448051948051948
#
# 漏警率： 0.9717816683831102
# 虚警率： 0.5551948051948052
# F1: 0.05306992058880496
# fpr: 0.0030186414348255895
# ****************************************
#                     Real +          Real -
#    Predict +          147             183
#    Predict -         4708            56465
#
# 准确率： 0.9204754239630587
# 召回率： 0.030278063851699278
# 精准率： 0.44545454545454544
#
# 漏警率： 0.9697219361483007
# 虚警率： 0.5545454545454546
# F1: 0.056702025072324004
# fpr: 0.003230475921480017
# ****************************************
#                     Real +          Real -
#    Predict +          160             197
#    Predict -         4695            56451
#
# 准确率： 0.9204591645935971
# 召回率： 0.032955715756951595
# 精准率： 0.4481792717086835
#
# 漏警率： 0.9670442842430484
# 虚警率： 0.5518207282913166
# F1: 0.06139677666922486
# fpr: 0.003477616155910182
# ****************************************
#                     Real +          Real -
#    Predict +          172             217
#    Predict -         4683            56431
#
# 准确率： 0.9203290896379038
# 召回率： 0.03542739443872297
# 精准率： 0.442159383033419
#
# 漏警率： 0.964572605561277
# 虚警率： 0.557840616966581
# F1: 0.06559877955758964
# fpr: 0.0038306736336675613
# ****************************************
#                     Real +          Real -
#    Predict +          183             247
#    Predict -         4672            56401
#
# 准确率： 0.9200201616181325
# 召回率： 0.03769309989701339
# 精准率： 0.4255813953488372
#
# 漏警率： 0.9623069001029866
# 虚警率： 0.5744186046511628
# F1: 0.06925260170293282
# fpr: 0.00436025985030363
# ****************************************
#                     Real +          Real -
#    Predict +          194             269
#    Predict -         4661            56379
#
# 准确率： 0.9198413085540543
# 召回率： 0.03995880535530381
# 精准率： 0.4190064794816415
#
# 漏警率： 0.9600411946446962
# 虚警率： 0.5809935205183585
# F1: 0.07295975930801053
# fpr: 0.004748623075836746
# ****************************************
#                     Real +          Real -
#    Predict +          208             291
#    Predict -         4647            56357
#
# 准确率： 0.919711233598361
# 召回率： 0.042842430484037075
# 精准率： 0.4168336673346693
#
# 漏警率： 0.9571575695159629
# 虚警率： 0.5831663326653307
# F1: 0.07769891669779604
# fpr: 0.005136986301369863
# ****************************************
#                     Real +          Real -
#    Predict +          234             326
#    Predict -         4621            56322
#
# 准确率： 0.9195648992732062
# 召回率： 0.04819773429454171
# 精准率： 0.41785714285714287
#
# 漏警率： 0.9518022657054583
# 虚警率： 0.5821428571428571
# F1: 0.08642659279778393
# fpr: 0.005754836887445276
# ****************************************
#                     Real +          Real -
#    Predict +          254             358
#    Predict -         4601            56290
#
# 准确率： 0.9193697868396663
# 召回率： 0.05231719876416066
# 精准率： 0.4150326797385621
#
# 漏警率： 0.9476828012358394
# 虚警率： 0.5849673202614378
# F1: 0.09292116334369856
# fpr: 0.006319728851857082
# ****************************************
#                     Real +          Real -
#    Predict +          277             391
#    Predict -         4578            56257
#
# 准确率： 0.9192071931450498
# 召回率： 0.05705458290422245
# 精准率： 0.41467065868263475
#
# 漏警率： 0.9429454170957775
# 虚警率： 0.5853293413173652
# F1: 0.10030780372985697
# fpr: 0.006902273690156758
# ****************************************
#                     Real +          Real -
#    Predict +          301             421
#    Predict -         4554            56227
#
# 准确率： 0.91910963692828
# 召回率： 0.06199794026776519
# 精准率： 0.4168975069252078
#
# 漏警率： 0.9380020597322348
# 虚警率： 0.5831024930747922
# F1: 0.10794333871256949
# fpr: 0.007431859906792826
# ****************************************
#                     Real +          Real -
#    Predict +          319             459
#    Predict -         4536            56189
#
# 准确率： 0.9187844495390469
# 召回率： 0.06570545829042225
# 精准率： 0.41002570694087404
#
# 漏警率： 0.9342945417095777
# 虚警率： 0.589974293059126
# F1: 0.11326113971240902
# fpr: 0.008102669114531846
# ****************************************
#                     Real +          Real -
#    Predict +          343             504
#    Predict -         4512            56144
#
# 准确率： 0.9184430027803522
# 召回率： 0.07064881565396498
# 精准率： 0.4049586776859504
#
# 漏警率： 0.929351184346035
# 虚警率： 0.5950413223140496
# F1: 0.12030866362679761
# fpr: 0.008897048439485949
# ****************************************
#                     Real +          Real -
#    Predict +          375             563
#    Predict -         4480            56085
#
# 准确率： 0.9180039998048876
# 召回率： 0.07723995880535531
# 精准率： 0.3997867803837953
#
# 漏警率： 0.9227600411946447
# 虚警率： 0.6002132196162047
# F1: 0.1294665976178146
# fpr: 0.009938567998870216
# ****************************************
#                     Real +          Real -
#    Predict +          403             609
#    Predict -         4452            56039
#
# 准确率： 0.9177113311545778
# 召回率： 0.08300720906282183
# 精准率： 0.39822134387351776
#
# 漏警率： 0.9169927909371782
# 虚警率： 0.6017786561264822
# F1: 0.1373785580364752
# fpr: 0.010750600197712188
# ****************************************
#                     Real +          Real -
#    Predict +          432             661
#    Predict -         4423            55987
#
# 准确率： 0.9173373656569598
# 召回率： 0.0889804325437693
# 精准率： 0.39524245196706315
#
# 漏警率： 0.9110195674562307
# 虚警率： 0.6047575480329368
# F1: 0.14525891055817083
# fpr: 0.011668549639881372
# ****************************************
#                     Real +          Real -
#    Predict +          458             721
#    Predict -         4397            55927
#
# 准确率： 0.9167845470952637
# 召回率： 0.09433573635427395
# 精准率： 0.3884648006785411
#
# 漏警率： 0.905664263645726
# 虚警率： 0.6115351993214588
# F1: 0.15180643022870402
# fpr: 0.01272772207315351
# ****************************************
#                     Real +          Real -
#    Predict +          482             781
#    Predict -         4373            55867
#
# 准确率： 0.9161992097946442
# 召回率： 0.09927909371781668
# 精准率： 0.38163103721298497
#
# 漏警率： 0.9007209062821833
# 虚警率： 0.618368962787015
# F1: 0.15756783262504087
# fpr: 0.013786894506425645
# ****************************************
#                     Real +          Real -
#    Predict +          511             845
#    Predict -         4344            55803
#
# 准确率： 0.9156301318634863
# 召回率： 0.10525231719876416
# 精准率： 0.37684365781710916
#
# 漏警率： 0.8947476828012358
# 虚警率： 0.6231563421828908
# F1: 0.16454677185638383
# fpr: 0.01491667843524926
# ****************************************
#                     Real +          Real -
#    Predict +          546             912
#    Predict -         4309            55736
#
# 准确率： 0.9151098320407135
# 召回率： 0.11246138002059733
# 精准率： 0.37448559670781895
#
# 漏警率： 0.8875386199794026
# 虚警率： 0.6255144032921811
# F1: 0.17297639790907654
# fpr: 0.016099420985736478
# ****************************************
#                     Real +          Real -
#    Predict +          586             994
#    Predict -         4269            55654
#
# 准确率： 0.914426938523324
# 召回率： 0.12070030895983522
# 精准率： 0.37088607594936707
#
# 漏警率： 0.8792996910401648
# 虚警率： 0.6291139240506329
# F1: 0.18212898212898213
# fpr: 0.01754695664454173
# ****************************************
#                     Real +          Real -
#    Predict +          620            1083
#    Predict -         4235            55565
#
# 准确率： 0.9135326732029332
# 召回率： 0.12770339855818744
# 精准率： 0.364063417498532
#
# 漏警率： 0.8722966014418125
# 虚警率： 0.635936582501468
# F1: 0.18908203720646538
# fpr: 0.019118062420562066
# ****************************************
#                     Real +          Real -
#    Predict +          663            1171
#    Predict -         4192            55477
#
# 准确率： 0.9128010015771588
# 召回率： 0.1365602471678682
# 精准率： 0.36150490730643403
#
# 漏警率： 0.8634397528321318
# 虚警率： 0.638495092693566
# F1: 0.19823590970249666
# fpr: 0.020671515322694536
# ****************************************
#                     Real +          Real -
#    Predict +          709            1288
#    Predict -         4146            55360
#
# 准确率： 0.9116465863453815
# 召回率： 0.14603501544799177
# 精准率： 0.3550325488232349
#
# 漏警率： 0.8539649845520082
# 虚警率： 0.6449674511767651
# F1: 0.2069468768242849
# fpr: 0.022736901567575202
# ****************************************
#                     Real +          Real -
#    Predict +          754            1420
#    Predict -         4101            55228
#
# 准确率： 0.9102320212022178
# 召回率： 0.1553038105046344
# 精准率： 0.3468261269549218
#
# 漏警率： 0.8446961894953656
# 虚警率： 0.6531738730450782
# F1: 0.2145397638355385
# fpr: 0.025067080920773904
# ****************************************
#                     Real +          Real -
#    Predict +          806            1564
#    Predict -         4049            55084
#
# 准确率： 0.9087361592117458
# 召回率： 0.16601441812564366
# 精准率： 0.340084388185654
#
# 漏警率： 0.8339855818743563
# 虚警率： 0.659915611814346
# F1: 0.22311418685121107
# fpr: 0.02760909476062703
# ****************************************
#                     Real +          Real -
#    Predict +          852            1706
#    Predict -         4003            54942
#
# 准确率： 0.9071752597434272
# 召回率： 0.17548918640576724
# 精准率： 0.33307271305707586
#
# 漏警率： 0.8245108135942327
# 虚警率： 0.6669272869429241
# F1: 0.22986645082962362
# fpr: 0.03011580285270442
# ****************************************
#                     Real +          Real -
#    Predict +          890            1896
#    Predict -         3965            54752
#
# 准确率： 0.904703835585256
# 召回率： 0.18331616889804325
# 精准率： 0.3194544149318019
#
# 漏警率： 0.8166838311019567
# 虚警率： 0.6805455850681981
# F1: 0.23295380185839554
# fpr: 0.03346984889139952
# ****************************************
#                     Real +          Real -
#    Predict +          956            2109
#    Predict -         3899            54539
#
# 准确率： 0.9023137082743932
# 召回率： 0.19691040164778578
# 精准率： 0.3119086460032626
#
# 漏警率： 0.8030895983522142
# 虚警率： 0.6880913539967374
# F1: 0.24141414141414144
# fpr: 0.0372299110295156
# ****************************************
#                     Real +          Real -
#    Predict +         1028            2299
#    Predict -         3827            54349
#
# 准确率： 0.9003951026779181
# 召回率： 0.211740473738414
# 精准率： 0.30898707544334236
#
# 漏警率： 0.788259526261586
# 虚警率： 0.6910129245566576
# F1: 0.2512833048154486
# fpr: 0.040583957068210705
# ****************************************
#                     Real +          Real -
#    Predict +         1094            2550
#    Predict -         3761            54098
#
# 准确率： 0.8973871193275125
# 召回率： 0.22533470648815654
# 精准率： 0.30021953896816683
#
# 漏警率： 0.7746652935118434
# 虚警率： 0.6997804610318332
# F1: 0.25744205200611836
# fpr: 0.04501482841406581
# ****************************************
#                     Real +          Real -
#    Predict +         1189            2844
#    Predict -         3666            53804
#
# 准确率： 0.8941515048046437
# 召回率： 0.24490216271884654
# 精准率： 0.2948177535333499
#
# 漏警率： 0.7550978372811534
# 虚警率： 0.7051822464666502
# F1: 0.26755175517551755
# fpr: 0.05020477333709928
# ****************************************
#                     Real +          Real -
#    Predict +         1263            3180
#    Predict -         3592            53468
#
# 准确率： 0.8898915500056908
# 召回率： 0.2601441812564367
# 精准率： 0.28426738690074277
#
# 漏警率： 0.7398558187435633
# 虚警率： 0.7157326130992572
# F1: 0.2716713271671327
# fpr: 0.056136138963423246
# ****************************************
#                     Real +          Real -
#    Predict +         1345            3518
#    Predict -         3510            53130
#
# 准确率： 0.8857291514235078
# 召回率： 0.27703398558187436
# 精准率： 0.2765782438823771
#
# 漏警率： 0.7229660144181256
# 虚警率： 0.7234217561176228
# F1: 0.2768059271455032
# fpr: 0.06210281033752295
# ****************************************
#                     Real +          Real -
#    Predict +         1449            3948
#    Predict -         3406            52700
#
# 准确率： 0.8804285969790091
# 召回率： 0.2984552008238929
# 精准率： 0.26848249027237353
#
# 漏警率： 0.7015447991761071
# 虚警率： 0.7315175097276265
# F1: 0.28267655091689425
# fpr: 0.0696935461093066
# ****************************************
#                     Real +          Real -
#    Predict +         1559            4414
#    Predict -         3296            52234
#
# 准确率： 0.874640261450661
# 召回率： 0.3211122554067971
# 精准率： 0.2610078687426754
#
# 漏警率： 0.6788877445932029
# 虚警率： 0.7389921312573247
# F1: 0.2879571481344662
# fpr: 0.07791978534105352
# ****************************************
#                     Real +          Real -
#    Predict +         1667            4942
#    Predict -         3188            51706
#
# 准确率： 0.8678113262767669
# 召回率： 0.34335736354273944
# 精准率： 0.25223180511423815
#
# 漏警率： 0.6566426364572606
# 虚警率： 0.7477681948857618
# F1: 0.29082344731332865
# fpr: 0.08724050275384833
# ****************************************
#                     Real +          Real -
#    Predict +         1792            5561
#    Predict -         3063            51087
#
# 准确率： 0.8597791977627107
# 召回率： 0.3691040164778579
# 精准率： 0.24371005031959744
#
# 漏警率： 0.6308959835221422
# 虚警率： 0.7562899496804025
# F1: 0.29357798165137616
# fpr: 0.0981676316904392
# ****************************************
#                     Real +          Real -
#    Predict +         1912            6292
#    Predict -         2943            50356
#
# 准确率： 0.8498447230216413
# 召回率： 0.39382080329557156
# 精准率： 0.23305704534373475
#
# 漏警率： 0.6061791967044284
# 虚警率： 0.7669429546562653
# F1: 0.2928248717359675
# fpr: 0.11107188250247141
# ****************************************
#                     Real +          Real -
#    Predict +         2050            7154
#    Predict -         2805            49494
#
# 准确率： 0.8380729395314049
# 召回率： 0.42224510813594235
# 精准率： 0.22272924815297696
#
# 漏警率： 0.5777548918640576
# 虚警率： 0.777270751847023
# F1: 0.2916281385589302
# fpr: 0.12628865979381443
# ****************************************
#                     Real +          Real -
#    Predict +         2207            8151
#    Predict -         2648            48497
#
# 准确率： 0.8244150691836171
# 召回率： 0.45458290422245107
# 精准率： 0.2130720216257965
#
# 漏警率： 0.5454170957775489
# 虚警率： 0.7869279783742035
# F1: 0.29014658515743114
# fpr: 0.14388857506001976
# ****************************************
#                     Real +          Real -
#    Predict +         2366            9401
#    Predict -         2489            47247
#
# 准确率： 0.8066760971009544
# 召回率： 0.48733264675592175
# 精准率： 0.20107079119571683
#
# 漏警率： 0.5126673532440782
# 虚警率： 0.7989292088042832
# F1: 0.2846829503068223
# fpr: 0.16595466741985596
# ****************************************
#                     Real +          Real -
#    Predict +         2550            10899
#    Predict -         2305            45749
#
# 准确率： 0.7853112856283433
# 召回率： 0.525231719876416
# 精准率： 0.18960517510595584
#
# 漏警率： 0.47476828012358396
# 虚警率： 0.8103948248940441
# F1: 0.27862762237762234
# fpr: 0.19239867250388362
# ****************************************
#                     Real +          Real -
#    Predict +         2774            12580
#    Predict -         2081            44068
#
# 准确率： 0.761621384322716
# 召回率： 0.5713697219361483
# 精准率： 0.18066953236941513
#
# 漏警率： 0.4286302780638517
# 虚警率： 0.8193304676305848
# F1: 0.27453114948785196
# fpr: 0.22207315350939133
# ****************************************
#                     Real +          Real -
#    Predict +         2993            14818
#    Predict -         1862            41830
#
# 准确率： 0.72879371737964
# 召回率： 0.6164778578784758
# 精准率： 0.16804222109932065
#
# 漏警率： 0.38352214212152425
# 虚警率： 0.8319577789006793
# F1: 0.2640960028236125
# fpr: 0.261580285270442
# ****************************************
#                     Real +          Real -
#    Predict +         3264            17626
#    Predict -         1591            39022
#
# 准确率： 0.6875436970554282
# 召回率： 0.6722966014418126
# 精准率： 0.15624700813786502
#
# 漏警率： 0.3277033985581874
# 虚警率： 0.8437529918621349
# F1: 0.2535637987958827
# fpr: 0.311149555147578
# ****************************************
#                     Real +          Real -
#    Predict +         3563            21288
#    Predict -         1292            35360
#
# 准确率： 0.6328634375558916
# 召回率： 0.7338825952626159
# 精准率： 0.14337451209206872
#
# 漏警率： 0.2661174047373841
# 虚警率： 0.8566254879079312
# F1: 0.23988419847842185
# fpr: 0.3757943793249541
# ****************************************
#                     Real +          Real -
#    Predict +         3876            26284
#    Predict -          979            30364
#
# 准确率： 0.556720810366974
# 召回率： 0.7983522142121524
# 精准率： 0.12851458885941644
#
# 漏警率： 0.2016477857878476
# 虚警率： 0.8714854111405835
# F1: 0.22139083250035696
# fpr: 0.4639881372687473
# ****************************************
#                     Real +          Real -
#    Predict +         4232            33311
#    Predict -          623            23337
#
# 准确率： 0.4482545566882916
# 召回率： 0.8716786817713698
# 精准率： 0.11272407639240338
#
# 漏警率： 0.12832131822863024
# 虚警率： 0.8872759236075967
# F1: 0.1996320581159489
# fpr: 0.5880348820788024
# ****************************************
#                     Real +          Real -
#    Predict +         4610            43773
#    Predict -          245            12875
#
# 准确率： 0.2842950750369901
# 召回率： 0.9495365602471678
# 精准率： 0.09528140049190832
#
# 漏警率： 0.050463439752832184
# 虚警率： 0.9047185995080916
# F1: 0.173184567414253
# fpr: 0.7727192486936874
# ****************************************

# %%
x_list = np.arange(0, 1, 0.01)
plt.title('result')
plt.plot(x_list, accuracy_list, label='accuracy')
plt.plot(x_list, recall_list, label='recall')
plt.plot(x_list, precision_list, label='precision')
plt.plot(x_list, MissingAlarm_list, label='MissingAlarm')
plt.plot(x_list, FalseAlarm_list, label='FaleAlarm')
plt.plot(x_list, F1_list, label='F1')
plt.plot(x_list, fpr_list, label='fpr')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt  
plt.rcParams['font.sans-serif'] = [u'SimHei']
plt.rcParams['axes.unicode_minus'] = False
plt.plot(x_list, recall_list, label='recall')
plt.plot(x_list, fpr_list, label='fpr')
plt.plot(x_list, [recall_list[i] - fpr_list[i] for i in range(len(recall_list))], label='recall-fpr')
plt.legend()
plt.xlabel('阈值')
plt.ylabel('指标取值')
plt.title('召回率与FPR的差随阈值的变化图')
plt.show()

# %%
xg_cla.classes_
# Out:
# array([0, 1])

# %%
K_S = max([recall_list[i] - fpr_list[i] for i in range(len(recall_list))])
K_S
# Out:
# 0.36114704629423455

# %% [markdown]
# import matplotlib.pyplot as plt
# %matplotlib inline
#
# plt.rcParams['figure.figsize'] = [19.2, 10.8]
# plt.rcParams['figure.dpi'] = 600
# xgb.plot_tree(xg_cla,num_trees=0)
# # plt.savefig('./tmp.png')
# #plt.autoscale(enable=True, axis='both', tight=None)
# plt.show()

# %% [markdown]
# plt.rcParams['figure.figsize'] = [10, 10]
# xgb.plot_importance(xg_cla)
# plt.show()

# %% [markdown]
# help(xg_cla.predict_proba)
